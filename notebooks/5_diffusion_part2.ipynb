# %% [markdown]
# # Diffusion Part 2
# Now that we have walked through the diffusion process, we can abstract everything away into some classes and folders. We have stored our U-Net in a python file `unet.py`, the device identification and data loading into a `utils.py` files, and finally, the main diffusion algorthim in the `ddpm.py` file. From here on, we call the `DDPM` class the `scheduler`...because that's essentially what it does.
#
# So now we can simply import all these classes and run the diffusion process in a few lines of code.

# %%
import matplotlib.pyplot as plt
import torch
import torch.optim as optim
import sys
import numpy as np

# %% [markdown]
# ## Get the data

# %%
sys.path.append('..') # Add parent directory to path so we can grab the code that we need in the diffusion_models directory
from diffusion_models.utils import *
from diffusion_models.unet import UNetSmol
from diffusion_models.ddpm import DDPM

DATA_PATH = '../data/'
train_dataset, test_dataset = get_mnist(DATA_PATH)

# %%
device = get_device()
print(f"Using device: {device}")
# Out:
# Using device: mps

# %% [markdown]
# ## Get the model and optimizer

# %%
unet = UNetSmol(input_channels=1,
                output_channels=1,
                block_channels=[32,64,128])
optimizer = optim.AdamW(unet.parameters(), lr=0.001)

# %% [markdown]
# ### Define the scheduler
# We will increase the steps to 500. In many bigger and better models, the steps could be in the thousands.

# %%
scheduler = DDPM(
    model = unet,
    optimizer = optimizer,
    T = 500,
    start = 0.001,
    end = 0.02,
    ntasks_per_node=1,
    device=device,
    checkpoint_in="../examples/checkpoint.pt",
    checkpoint_out="",
)
# Out:
# [DDPM_INFO] host+device: MY7H4RKXL9.local+mps:0, world_size: 1, rank: 0, local_rank: 0

# %% [markdown]
# ## Train for a few epochs
# Here, "a few" epochs is actually 20. This will probably take over an hour to run on something like a Macbook Pro, so you might want to reduce this down (or increase it if you want to push the model!)

# %%
batch_size = 32
losses, t_values = scheduler.train(train_dataset, epochs=20, batch_size=batch_size)
# Out:
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 90.30it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 1/20, Time: 20.773 s, Images: 1875, Loss: 0.0599
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 91.21it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 2/20, Time: 20.557 s, Images: 1875, Loss: 0.0436
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 90.45it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 3/20, Time: 20.731 s, Images: 1875, Loss: 0.0400
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 89.95it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 4/20, Time: 20.846 s, Images: 1875, Loss: 0.0389
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 89.61it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 5/20, Time: 20.925 s, Images: 1875, Loss: 0.0380
# Training: 100%|█████████████████████████████| 1875/1875 [00:21<00:00, 89.26it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 6/20, Time: 21.007 s, Images: 1875, Loss: 0.0369
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 89.76it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 7/20, Time: 20.890 s, Images: 1875, Loss: 0.0362
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 89.91it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 8/20, Time: 20.856 s, Images: 1875, Loss: 0.0357
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 90.17it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 9/20, Time: 20.795 s, Images: 1875, Loss: 0.0351
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 90.00it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 10/20, Time: 20.835 s, Images: 1875, Loss: 0.0348
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 89.92it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 11/20, Time: 20.854 s, Images: 1875, Loss: 0.0350
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 90.02it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 12/20, Time: 20.829 s, Images: 1875, Loss: 0.0346
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 89.81it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 13/20, Time: 20.878 s, Images: 1875, Loss: 0.0340
# Training: 100%|█████████████████████████████| 1875/1875 [00:21<00:00, 88.66it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 14/20, Time: 21.149 s, Images: 1875, Loss: 0.0338
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 90.14it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 15/20, Time: 20.802 s, Images: 1875, Loss: 0.0338
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 90.09it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 16/20, Time: 20.814 s, Images: 1875, Loss: 0.0335
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 89.46it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 17/20, Time: 20.961 s, Images: 1875, Loss: 0.0337
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 89.75it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 18/20, Time: 20.891 s, Images: 1875, Loss: 0.0333
# Training: 100%|█████████████████████████████| 1875/1875 [00:20<00:00, 89.67it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 19/20, Time: 20.911 s, Images: 1875, Loss: 0.0333
# Training: 100%|█████████████████████████████| 1875/1875 [00:21<00:00, 89.04it/s]
# [DDPM_INFO] MY7H4RKXL9.local+mps:0 - Epoch: 20/20, Time: 21.058 s, Images: 1875, Loss: 0.0332

# %% [markdown]
# ## Loss curves
# It is well know that loss curves in diffusion models seem to suddenly decrease and then become very noisy and "converge". This behaviour is expected in diffusion models. Predicting noise is actually fairly easy when t is very high, and the model therefore becomes very good early on in the training. However, the model also needs to be able to predict low noise (i.e. when t is small), which it remains bad at.
#
# When you just look at the loss for all values of t mixed up, you can't see the progress. However if you look at each loss curves for only a single value of t, you will see improvement.
#
# Let's test this theory but first plotting the overall loss for each batch, and then the loss function for each time step.

# %%
n_batches = len(losses) // batch_size
n_sample = n_batches * batch_size

# Calculate which training step (batch number) each sample came from
training_steps = np.repeat(range(n_batches + 1), batch_size)[:len(losses)]
batch_losses = np.array(losses[:n_sample]).reshape(-1, batch_size).mean(axis=1)
batch_t = np.array(t_values[:n_sample]).reshape(-1, batch_size).mean(axis=1)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 5), sharex=True)

ax1.plot(range(len(batch_losses)), batch_losses)
ax1.set_xlabel('Step')
ax1.set_ylabel('Average Loss')
ax1.set_title('Average Loss per Batch')
ax1.grid()

# Select a few timesteps to plot
unique_t = np.unique(t_values)
n_curves = 10
# Use exponential spacing to get more samples at lower timesteps
indices = np.geomspace(1, len(unique_t), n_curves).astype(int) - 1
selected_t = unique_t[indices]

for t in selected_t[1:]:
    # Get losses and corresponding training steps for this timestep
    mask = np.array(t_values) == t
    t_losses = np.array(losses)[mask]
    t_steps = training_steps[mask]
    
    # Sort by training steps to ensure correct plotting order
    sort_idx = np.argsort(t_steps)
    t_losses = t_losses[sort_idx]
    t_steps = t_steps[sort_idx]

    window = 51  # Must be odd number
    smoothed_losses = np.convolve(t_losses, np.ones(window)/window, mode='valid')
    valid_steps = t_steps[window//2:-(window//2)]

    ax2.plot(t_steps, t_losses, alpha=0.2, lw=0.5)
    ax2.plot(valid_steps, smoothed_losses, label=f't={int(t)+1}', alpha=1., lw=0.5)
    
    
ax2.set_xlabel('Step')
ax2.set_ylabel('Average Loss')
ax2.set_title('Loss Curves for Different Timesteps')
ax2.set_ylim(-0.05, 1.25)
ax2.grid(True, alpha=0.3)
ax2.legend(bbox_to_anchor=(1.01, 1), loc='upper left')

plt.tight_layout()
fig.subplots_adjust(right=0.85)
plt.show()

# %% [markdown]
# Sure enough, the average loss per batch appears to have plateaued. When we look at the loss from individual timesteps however, we can see that the curves corresponding to low values of t are still decreasing. Had we stopped training based on the left plot, we would be depriving our model of learning those fine details and relationships.

# %% [markdown]
# ## Sampling
# Let's sample a number from the model, for example the number 6.

# %%
number = 6
x_ts = scheduler.sample(number, 10)
x_ts = np.array(x_ts)
# Out:
# 100%|████████████████████████████████████████| 500/500 [00:01<00:00, 329.01it/s]

# %%
plt.figure(figsize=(25,5))

single = x_ts[:, 0, :, :]

for t in range(scheduler.T):
    img = single[t].squeeze()
    ax = plt.subplot(10, 50, t + 1)
    ax.axis("off")
    plt.imshow(img, cmap="gray")

# %%
example = x_ts[-1]

plt.figure(figsize=(10, 5))
for i in range(10):
    img = example[i][0]
    ax = plt.subplot(2, 5, i + 1)
    ax.axis('off')
    plt.imshow(img, cmap='gray')

# %% [markdown]
# These results are really not bad considering that we only trained a very small model on a few epochs! Feel free to adjust the hyperparameters however you want. You'll notice that as you increase the number of epochs and the size of the model, you'll get significantly better results.

# %% [markdown]
# ## Next steps
# We built a lot of this from scratch. Surely someone has done this process for us already? Yes, they have! The `diffusers` library is a PyTorch library that implements the diffusion process and provides a lot of utilities to make the process easier.
